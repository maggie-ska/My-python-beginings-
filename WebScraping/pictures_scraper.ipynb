# %%
# Web scrape Wikipedia example 2
# %config Completer.use_jedi = False
import requests
import re
from bs4 import BeautifulSoup
from textblob import TextBlob
import os

# %%
# URL of our webpage
webpage_url = "https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_Republic_of_Ireland"
# webpage_url = "http://www.rte.ie"

# %%
# Try and scape all the images from a wikipedia page and save them to a sub folder
response = requests.get(webpage_url)

# Get the base path of the URL
from urllib.parse import urlparse

parsed_url = urlparse(webpage_url)
base_url = parsed_url[0] + "://" + parsed_url[1]
base_url
# Out:
# 'https://en.wikipedia.org'

# %%
# Make a subdirectory for our images
from datetime import datetime

# Auto genertae the folder name for the script to use by using the base url and the current time and date
folder_name = parsed_url[1] + datetime.now().strftime(" %m %d %Y %H-%M-%S")

if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f"Folder '{folder_name}' has been created.")
else:
    print(f"Folder '{folder_name}' already exists.")
# Out:
# Folder 'en.wikipedia.org 10 07 2020 10-11-55' has been created.

# %%
# Use BS to get all the image tags and get all the image scr values
html = response.content # html text
webpage_soup = BeautifulSoup(html)

# webpage_soup

# all_imgs is a list of img tag BS objects
all_imgs = webpage_soup.find_all("img")

print(len(all_imgs))
# Out:
# 49

# %%
# Make a list of the the image sources
img_source_urls = [ img["src"] for img in all_imgs]

# Some images ont he page may be the same so lets get the unique list
img_source_urls = list(set(img_source_urls))

img_source_urls
# images that start with a single '/'' are relative paths - to make the full url we add 'https://en.wikipedia.org'
# images that start with a double '//' are absolute paths - to make the full url we need to add just 'https:'
# Out:
# ['//upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Pandemic_pints.jpg/120px-Pandemic_pints.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Pharmacy_in_Ireland_during_the_2020_coronavirus_pandemic.jpg/120px-Pharmacy_in_Ireland_during_the_2020_coronavirus_pandemic.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/3/31/Queue_at_Irish_grocery_store_during_the_2020_coronavirus_pandemic.jpg/90px-Queue_at_Irish_grocery_store_during_the_2020_coronavirus_pandemic.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Collection_of_books_at_an_Irish_primary_school_during_the_2020_pandemic.jpg/90px-Collection_of_books_at_an_Irish_primary_school_during_the_2020_pandemic.jpg',
#  '/static/images/footer/wikimedia-button.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/02/Bus_%C3%89ireann_social_distancing_signs_on_a_bus_in_October_2020.jpg/120px-Bus_%C3%89ireann_social_distancing_signs_on_a_bus_in_October_2020.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Bram_Stoker_Park_social_distancing_01.jpg/120px-Bram_Stoker_Park_social_distancing_01.jpg',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/50f6aad61a2a8195a12d35a437de8ea0ebbcd3b8.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/d93ec6db9af8497e6acc3aae6d4017d823b46f8b.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/9bcd5f4ee98e1c15516d51f481f89072995f73e3.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/dc/Supermarket_social_distancing_signs.jpg/120px-Supermarket_social_distancing_signs.jpg',
#  '/static/images/footer/poweredby_mediawiki_88x31.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Porterstown_Park_in_lockdown.jpg/120px-Porterstown_Park_in_lockdown.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/48/Folder_Hexagonal_Icon.svg/16px-Folder_Hexagonal_Icon.svg.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/d03079a48ab27bc93af806e49216889d80e437ee.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/2/29/First_Day_of_School.jpg/120px-First_Day_of_School.jpg',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/f864b1831cf5f9c59cbd36212fd099de1598a3a0.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/1309fecde84289d41061dafede8fe6631f3406fd.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/43fdcb8fc91d4c156198e30d0a1175f25fbb37e3.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/d602cd929fed40d7eacad4fed77f36837efcf258.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/A_barber_shop_on_June%2C_29%2C_2020%2C_the_first_day_of_the_third_phase_of_the_lifting_of_public_health_restrictions.jpg/90px-A_barber_shop_on_June%2C_29%2C_2020%2C_the_first_day_of_the_third_phase_of_the_lifting_of_public_health_restrictions.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/SARS-CoV-2_%28Wikimedia_colors%29.svg/21px-SARS-CoV-2_%28Wikimedia_colors%29.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/49/Ersatz_protection_for_employees_deployed_in_a_grocery_store_during_the_2020_coronavirus_pandemic.jpg/120px-Ersatz_protection_for_employees_deployed_in_a_grocery_store_during_the_2020_coronavirus_pandemic.jpg',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/47846660e4a4ee01bcf502dada0369292e7ed5b4.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Shop_door_in_Ireland_during_the_2020_coronavirus_pandemic.jpg/90px-Shop_door_in_Ireland_during_the_2020_coronavirus_pandemic.jpg',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/ddb44f9a12d211217bb5a19bafb2531f8abf38f3.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Confirmed_cases_of_COVID-19_per_100k_inhabitants_in_Ireland.webm/220px--Confirmed_cases_of_COVID-19_per_100k_inhabitants_in_Ireland.webm.jpg',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/ebd6e5e2ae198fd765116fbca51f5e87111a48a2.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Irish_butcher_implementing_ad-hoc_social_distancing_measures_duing_the_2020_pandemic.jpg/120px-Irish_butcher_implementing_ad-hoc_social_distancing_measures_duing_the_2020_pandemic.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/f/fd/Portal-puzzle.svg/16px-Portal-puzzle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/2/22/Paramedic_wearing_PPE_mask%2C_eye_protection%2C_and_gown_in_Ireland_2020.jpg/67px-Paramedic_wearing_PPE_mask%2C_eye_protection%2C_and_gown_in_Ireland_2020.jpg',
#  '//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/e63766c203872be5a4d19b6ad40dc27bb2fd3eb7.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Confirmed_cases_of_COVID-19_in_Ireland_by_county.webm/220px--Confirmed_cases_of_COVID-19_in_Ireland_by_county.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Irish_grocery_store_showing_a_one-way_system%2C_instructions_on_social_distancing%2C_disposable_gloves_for_shoppers%2C_and_supplies_to_clean_trolleys.jpg/120px-Irish_grocery_store_showing_a_one-way_system%2C_instructions_on_social_distancing%2C_disposable_gloves_for_shoppers%2C_and_supplies_to_clean_trolleys.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/16/Garda_checkpoint_during_the_2020_coronavirus_pandemic.jpg/120px-Garda_checkpoint_during_the_2020_coronavirus_pandemic.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Sida-aids.png/21px-Sida-aids.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/a/a7/CoViD-19_IE.svg/440px-CoViD-19_IE.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/WHO_Rod.svg/9px-WHO_Rod.svg.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/27baceeb1e378f833266c4d178cfb20a83d22f62.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c6/%22Cocooning%22_during_the_2020_coronavirus_pandemic.jpg/90px-%22Cocooning%22_during_the_2020_coronavirus_pandemic.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Four_Provinces_Flag.svg/24px-Four_Provinces_Flag.svg.png',
#  '/api/rest_v1/page/graph/png/COVID-19_pandemic_in_the_Republic_of_Ireland/0/21ab9e592a106080b0342a1ddbab5466638bee0c.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/9/94/The_waiting_room_of_Connolly_Hosital_on_the_evening_of_11_April_2020._The_emptiness_is_unprecedented.jpg/120px-The_waiting_room_of_Connolly_Hosital_on_the_evening_of_11_April_2020._The_emptiness_is_unprecedented.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/3/31/Iarnr%C3%B3d_%C3%89ireann_Irish_rail_train_social_distancing_sign_-_July_2020.jpg/120px-Iarnr%C3%B3d_%C3%89ireann_Irish_rail_train_social_distancing_sign_-_July_2020.jpg']

# %%
# Test can we extract all the image names from the list of image sources
# with our regular expression
image_regex = r'/([\w.%-]+[.](png|gif|jpg|bmp))$'

for source in img_source_urls:
    match = re.search(image_regex,source)
    if match:
        print(match.group(1))
# Out:
# 120px-Pandemic_pints.jpg
# 120px-Pharmacy_in_Ireland_during_the_2020_coronavirus_pandemic.jpg
# 90px-Queue_at_Irish_grocery_store_during_the_2020_coronavirus_pandemic.jpg
# 90px-Collection_of_books_at_an_Irish_primary_school_during_the_2020_pandemic.jpg
# wikimedia-button.png
# 120px-Bus_%C3%89ireann_social_distancing_signs_on_a_bus_in_October_2020.jpg
# 120px-Bram_Stoker_Park_social_distancing_01.jpg
# 50f6aad61a2a8195a12d35a437de8ea0ebbcd3b8.png
# d93ec6db9af8497e6acc3aae6d4017d823b46f8b.png
# 9bcd5f4ee98e1c15516d51f481f89072995f73e3.png
# 120px-Supermarket_social_distancing_signs.jpg
# poweredby_mediawiki_88x31.png
# 120px-Porterstown_Park_in_lockdown.jpg
# 16px-Folder_Hexagonal_Icon.svg.png
# d03079a48ab27bc93af806e49216889d80e437ee.png
# 120px-First_Day_of_School.jpg
# f864b1831cf5f9c59cbd36212fd099de1598a3a0.png
# 1309fecde84289d41061dafede8fe6631f3406fd.png
# 43fdcb8fc91d4c156198e30d0a1175f25fbb37e3.png
# d602cd929fed40d7eacad4fed77f36837efcf258.png
# 90px-A_barber_shop_on_June%2C_29%2C_2020%2C_the_first_day_of_the_third_phase_of_the_lifting_of_public_health_restrictions.jpg
# 21px-SARS-CoV-2_%28Wikimedia_colors%29.svg.png
# 120px-Ersatz_protection_for_employees_deployed_in_a_grocery_store_during_the_2020_coronavirus_pandemic.jpg
# 47846660e4a4ee01bcf502dada0369292e7ed5b4.png
# 90px-Shop_door_in_Ireland_during_the_2020_coronavirus_pandemic.jpg
# ddb44f9a12d211217bb5a19bafb2531f8abf38f3.png
# 220px--Confirmed_cases_of_COVID-19_per_100k_inhabitants_in_Ireland.webm.jpg
# ebd6e5e2ae198fd765116fbca51f5e87111a48a2.png
# 120px-Irish_butcher_implementing_ad-hoc_social_distancing_measures_duing_the_2020_pandemic.jpg
# 16px-Portal-puzzle.svg.png
# 67px-Paramedic_wearing_PPE_mask%2C_eye_protection%2C_and_gown_in_Ireland_2020.jpg
# e63766c203872be5a4d19b6ad40dc27bb2fd3eb7.png
# 220px--Confirmed_cases_of_COVID-19_in_Ireland_by_county.webm.jpg
# 120px-Irish_grocery_store_showing_a_one-way_system%2C_instructions_on_social_distancing%2C_disposable_gloves_for_shoppers%2C_and_supplies_to_clean_trolleys.jpg
# 120px-Garda_checkpoint_during_the_2020_coronavirus_pandemic.jpg
# 21px-Sida-aids.png
# 440px-CoViD-19_IE.svg.png
# 9px-WHO_Rod.svg.png
# 27baceeb1e378f833266c4d178cfb20a83d22f62.png
# 90px-%22Cocooning%22_during_the_2020_coronavirus_pandemic.jpg
# 24px-Four_Provinces_Flag.svg.png
# 21ab9e592a106080b0342a1ddbab5466638bee0c.png
# 120px-The_waiting_room_of_Connolly_Hosital_on_the_evening_of_11_April_2020._The_emptiness_is_unprecedented.jpg
# 120px-Iarnr%C3%B3d_%C3%89ireann_Irish_rail_train_social_distancing_sign_-_July_2020.jpg

# %%
# Next step would be to iterate through all the img_source_urls
# Make a request and get each images content
# Write it to a file using the image name that we extract using our regex expression on each image url
# NOTE: Need to add on either 'http://', "https://" or the base_url dependng on weather the url starts with
# '//' for an absolute path or '/' for relative path
# NOTE: Check to see first if the regex re.search is None before attempt to request the URL

count_imgs_written = 0

for img_source in img_source_urls:
    # if the image path (src) starts with "//" its an absolute path
    if img_source.startswith("//"):
        full_img_url = parsed_url[0] + ":" + img_source
    # if the image path already starts with 'http' then it already the full url path
    elif img_source.startswith("http"):
        full_img_url = img_source
    # else we assume it's a relative path that starts with '/' and we need to concat with our base url
    else:
        full_img_url = base_url + img_source
    
    # The full and correct image URL should now be full_img_url
       
    
    # Make sure we have valid img filename using regex(.gif,.jpg etc....)
    # img_file_name will either be a re.match object or 'None' if there was no match
    img_file_name_match = re.search(image_regex,full_img_url)
    
    # print(full_img_url,"\n")
    
    # if img_file_name is None (Meaning that no re.MatchPObject was returned by re.search)
    if not img_file_name_match:
        print(f"COULD NOT FIND A VALID IMAGE NAME IN:\n '{full_img_url}'\n")
        continue # back to the start of the for loop if this happens
    
    # Otherwise we have an img_file_name and lets try and download that image file 
    # using the img url and write it the images folder with the file name
    # filepath show be like "images\myimage.jpg" which we can construct by
    # joining folder_name with the img_file_name
    # The inage file name should be h first group in out re.Match object img_file_name
    # due the way we constructed the regex expression 
    
    # Assign the group(1) string to img_file_name tp holdthe file name
    img_file_name = img_file_name_match.group(1)
    
    # Make the full file path where the file should be written
    filepath = os.path.join(folder_name,img_file_name)
     
    # Trying to write the files was casing an issue for one filename/filepath as the filepath was too
    # long for the winndows file system (over 250 characters)
    # ...so we can catch any exception thrown by the 'with open(filepath,"wb") as f:' statement
    try:
        # Open a file for writing bytes of data "wb"
        with open(filepath,"wb") as f:       
            # Get the contents of the image from the request for the image url
            image_content = requests.get(full_img_url).content
            # Write the image content to the file
            f.write(image_content)
            print(f"IMAGE:\n '{img_file_name}'has been written to FOLDER: '{folder_name}'\n")
            count_imgs_written += 1                  
    except:
        print(f"AN ERROR OCCURRED. COULD NOT WRITE FILE: {filepath}")
        
print(f"TOTAL NUMBER OF FILES WRITTEN: {count_imgs_written}")
# Out:
# IMAGE:
#  '120px-Pandemic_pints.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Pharmacy_in_Ireland_during_the_2020_coronavirus_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '90px-Queue_at_Irish_grocery_store_during_the_2020_coronavirus_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '90px-Collection_of_books_at_an_Irish_primary_school_during_the_2020_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'wikimedia-button.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Bus_%C3%89ireann_social_distancing_signs_on_a_bus_in_October_2020.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Bram_Stoker_Park_social_distancing_01.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '50f6aad61a2a8195a12d35a437de8ea0ebbcd3b8.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'd93ec6db9af8497e6acc3aae6d4017d823b46f8b.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '9bcd5f4ee98e1c15516d51f481f89072995f73e3.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Supermarket_social_distancing_signs.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'poweredby_mediawiki_88x31.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Porterstown_Park_in_lockdown.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '16px-Folder_Hexagonal_Icon.svg.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'd03079a48ab27bc93af806e49216889d80e437ee.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-First_Day_of_School.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'f864b1831cf5f9c59cbd36212fd099de1598a3a0.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '1309fecde84289d41061dafede8fe6631f3406fd.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '43fdcb8fc91d4c156198e30d0a1175f25fbb37e3.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'd602cd929fed40d7eacad4fed77f36837efcf258.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '90px-A_barber_shop_on_June%2C_29%2C_2020%2C_the_first_day_of_the_third_phase_of_the_lifting_of_public_health_restrictions.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '21px-SARS-CoV-2_%28Wikimedia_colors%29.svg.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Ersatz_protection_for_employees_deployed_in_a_grocery_store_during_the_2020_coronavirus_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '47846660e4a4ee01bcf502dada0369292e7ed5b4.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '90px-Shop_door_in_Ireland_during_the_2020_coronavirus_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'ddb44f9a12d211217bb5a19bafb2531f8abf38f3.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '220px--Confirmed_cases_of_COVID-19_per_100k_inhabitants_in_Ireland.webm.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  'ebd6e5e2ae198fd765116fbca51f5e87111a48a2.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Irish_butcher_implementing_ad-hoc_social_distancing_measures_duing_the_2020_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '16px-Portal-puzzle.svg.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '67px-Paramedic_wearing_PPE_mask%2C_eye_protection%2C_and_gown_in_Ireland_2020.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# COULD NOT FIND A VALID IMAGE NAME IN:
#  'https://en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1'
#
# IMAGE:
#  'e63766c203872be5a4d19b6ad40dc27bb2fd3eb7.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '220px--Confirmed_cases_of_COVID-19_in_Ireland_by_county.webm.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# AN ERROR OCCURRED. COULD NOT WRITE FILE: en.wikipedia.org 10 07 2020 10-11-55\120px-Irish_grocery_store_showing_a_one-way_system%2C_instructions_on_social_distancing%2C_disposable_gloves_for_shoppers%2C_and_supplies_to_clean_trolleys.jpg
# IMAGE:
#  '120px-Garda_checkpoint_during_the_2020_coronavirus_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '21px-Sida-aids.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '440px-CoViD-19_IE.svg.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '9px-WHO_Rod.svg.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '27baceeb1e378f833266c4d178cfb20a83d22f62.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '90px-%22Cocooning%22_during_the_2020_coronavirus_pandemic.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '24px-Four_Provinces_Flag.svg.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '21ab9e592a106080b0342a1ddbab5466638bee0c.png'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-The_waiting_room_of_Connolly_Hosital_on_the_evening_of_11_April_2020._The_emptiness_is_unprecedented.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# IMAGE:
#  '120px-Iarnr%C3%B3d_%C3%89ireann_Irish_rail_train_social_distancing_sign_-_July_2020.jpg'has been written to FOLDER: 'en.wikipedia.org 10 07 2020 10-11-55'
#
# TOTAL NUMBER OF FILES WRITTEN: 43
