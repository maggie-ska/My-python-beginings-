# %% [markdown]
# ### great to show therelationship between two sets of values and see if there is a corelation between them

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

#this could be the satisfaction level measured from 1 to 10 
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

#this could be sample size like for example population
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
         538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]

#s = size of dots
#c='color'
#marker = 'x'
plt.scatter(x,y,s=sizes,c=colors,cmap = 'Greens',edgecolor='black',linewidth = 1,alpha =0.75)

#adding our color dots and label to it so we know what this represents
cbar = plt.colorbar()
cbar.set_label('Satisfaction')

sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
         538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]


plt.tight_layout()

plt.show()

# %% [markdown]
# ## real life data

# %%
data = pd.read_csv('data3.csv',delimiter= ';')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count,likes,edgecolor='black',linewidth = 1,alpha =0.75)

#setting up the log scale will improve the look of our plot if we have an out lier that is messing it up
plt.xscale('log')
plt.yscale('log')
plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')
# Out:
# Text(0, 0.5, 'Total Likes')
